# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_excel('heart_data_500_samples.xlsx')
print(data.head())
print(data.info())
# Out:
#    Age  Sex  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0   67    1                0                     176          148
# 1   57    1                1                     155          551
# 2   43    1                0                     125          519
# 3   71    1                0                     123          285
# 4   36    0                0                     122          488
#
#    Fasting Blood Sugar > 120 mg/dl  Resting ECG  Max Heart Rate Achieved  \
# 0                                1            1                      168
# 1                                0            1                       98
# 2                                1            0                      113
# 3                                0            2                      156
# 4                                1            1                       87
#
#    Exercise-Induced Angina  ST Depression  Slope of ST Segment  \
# 0                        1            5.6                    2
# 1                        1            4.2                    1
# 2                        1            0.8                    0
# 3                        0            6.2                    2
# 4                        1            3.3                    2
#
#    Number of Major Vessels  Thalassemia  Target
# 0                        1            1       0
# 1                        3            2       1
# 2                        0            1       1
# 3                        0            2       0
# 4                        2            3       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              500 non-null    int64
#  1   Sex                              500 non-null    int64
#  2   Chest Pain Type                  500 non-null    int64
#  3   Resting Blood Pressure           500 non-null    int64
#  4   Cholesterol                      500 non-null    int64
#  5   Fasting Blood Sugar > 120 mg/dl  500 non-null    int64
#  6   Resting ECG                      500 non-null    int64
#  7   Max Heart Rate Achieved          500 non-null    int64
#  8   Exercise-Induced Angina          500 non-null    int64
#  9   ST Depression                    500 non-null    float64
#  10  Slope of ST Segment              500 non-null    int64
#  11  Number of Major Vessels          500 non-null    int64
#  12  Thalassemia                      500 non-null    int64
#  13  Target                           500 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 54.8 KB
# None

# %%
print(data.isnull().sum())
data1=data.dropna()
print(data1.describe())
# Out:
# Age                                0
# Sex                                0
# Chest Pain Type                    0
# Resting Blood Pressure             0
# Cholesterol                        0
# Fasting Blood Sugar > 120 mg/dl    0
# Resting ECG                        0
# Max Heart Rate Achieved            0
# Exercise-Induced Angina            0
# ST Depression                      0
# Slope of ST Segment                0
# Number of Major Vessels            0
# Thalassemia                        0
# Target                             0
# dtype: int64
#               Age         Sex  Chest Pain Type  Resting Blood Pressure  \
# count  500.000000  500.000000        500.00000               500.00000
# mean    52.980000    0.468000          1.44600               145.80200
# std     13.800598    0.499475          1.09795                30.52058
# min     29.000000    0.000000          0.00000                94.00000
# 25%     42.000000    0.000000          0.00000               119.00000
# 50%     54.000000    0.000000          1.00000               146.00000
# 75%     64.000000    1.000000          2.00000               174.00000
# max     76.000000    1.000000          3.00000               199.00000
#
#        Cholesterol  Fasting Blood Sugar > 120 mg/dl  Resting ECG  \
# count   500.000000                       500.000000   500.000000
# mean    349.134000                         0.522000     0.960000
# std     130.505891                         0.500016     0.817151
# min     126.000000                         0.000000     0.000000
# 25%     240.500000                         0.000000     0.000000
# 50%     351.500000                         1.000000     1.000000
# 75%     463.500000                         1.000000     2.000000
# max     563.000000                         1.000000     2.000000
#
#        Max Heart Rate Achieved  Exercise-Induced Angina  ST Depression  \
# count               500.000000               500.000000     500.000000
# mean                137.414000                 0.510000       3.183000
# std                  38.168472                 0.500401       1.763823
# min                  71.000000                 0.000000       0.000000
# 25%                 105.000000                 0.000000       1.700000
# 50%                 138.000000                 1.000000       3.200000
# 75%                 171.000000                 1.000000       4.725000
# max                 201.000000                 1.000000       6.200000
#
#        Slope of ST Segment  Number of Major Vessels  Thalassemia      Target
# count           500.000000               500.000000   500.000000  500.000000
# mean              1.070000                 1.514000     2.054000    0.504000
# std               0.811429                 1.133302     0.815115    0.500485
# min               0.000000                 0.000000     1.000000    0.000000
# 25%               0.000000                 0.000000     1.000000    0.000000
# 50%               1.000000                 2.000000     2.000000    1.000000
# 75%               2.000000                 3.000000     3.000000    1.000000
# max               2.000000                 3.000000     3.000000    1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
plt.title('Heart Disease Prediction')
plt.show()
